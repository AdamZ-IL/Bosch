# %%
import numpy as np
import pandas as pd
import missingno as msno
import timeit
import dask.dataframe as dd

# %matplotlib inline

# %%
reader = pd.read_csv('../Data/train_numeric.csv', iterator=True, chunksize=50000, low_memory=False)

one_row = pd.read_csv('../Data/train_numeric.csv',  nrows=1)


reader.get_chunk(4)
# Out:
#    Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# 0   4     0.030    -0.034    -0.197    -0.179     0.118      0.116     -0.015
# 1   6       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2   7     0.088     0.086     0.003    -0.052     0.161      0.025     -0.015
# 3   9    -0.036    -0.064     0.294     0.330     0.074      0.161      0.022
#
#    L0_S0_F14  L0_S0_F16    ...     L3_S50_F4245  L3_S50_F4247  L3_S50_F4249  \
# 0     -0.032      0.020    ...              NaN           NaN           NaN
# 1        NaN        NaN    ...              NaN           NaN           NaN
# 2     -0.072     -0.225    ...              NaN           NaN           NaN
# 3      0.128     -0.026    ...              NaN           NaN           NaN
#
#    L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  L3_S51_F4258  L3_S51_F4260  \
# 0           NaN           NaN           NaN           NaN           NaN
# ...

# %%
test = pd.melt(reader.get_chunk(4), id_vars = 'Id', value_vars=list(one_row.columns[1:-1]))

# %%
final = []

i=0

for chunk in reader:

    print('step: '+str(i))
    
    df = pd.melt(chunk, id_vars = 'Id', value_vars=list(one_row.columns[1:-1]))


    df['value'] = (df['value']/df['value'])

    print('rename step: ')
    #%time df['variable_new'] = df['variable'].str.extract('(.*_.*_)', expand=True)
    # %time df['variable_new'] = df['variable'].str.rsplit('_', expand=False,n=1).str.get(0)
    
    
    ddf = dd.from_pandas(df, chunksize=200000)



    print('group by step: ')
    # %time ddf_grouped = ddf.groupby(['Id','variable_new'], sort=False).value.max().compute().reset_index()
    
    
    df_grouped = pd.DataFrame(ddf_grouped)



    df_pivot = pd.pivot_table(df_grouped, index='Id', columns='variable_new',
                             values='value', aggfunc=np.max).reset_index()




#     col = ['Id', 'L0_S0_', 'L0_S1_', 'L0_S2_', 'L0_S3_', 'L0_S4_', 'L0_S5_', 'L0_S6_', 'L0_S7_', 'L0_S8_', 'L0_S9_',
#      'L0_S10_', 'L0_S11_', 'L0_S12_', 'L0_S13_', 'L0_S14_', 'L0_S15_',
#      'L0_S16_', 'L0_S17_', 'L0_S18_', 'L0_S19_',  'L0_S20_', 'L0_S21_', 'L0_S22_', 
#      'L0_S23_', 'L1_S24_', 'L1_S25_', 'L2_S26_', 'L2_S27_', 'L2_S28_',
#      'L3_S29_', 'L3_S30_', 'L3_S31_', 'L3_S32_', 'L3_S33_', 'L3_S34_', 'L3_S35_',
#      'L3_S36_', 'L3_S37_', 'L3_S38_', 'L3_S39_', 'L3_S40_', 'L3_S41_', 'L3_S43_',
#      'L3_S44_', 'L3_S45_', 'L3_S47_', 'L3_S48_', 'L3_S49_', 'L3_S50_', 'L3_S51_']

    col = ['Id', 'L0_S0', 'L0_S1', 'L0_S2', 'L0_S3', 'L0_S4', 'L0_S5', 'L0_S6', 'L0_S7', 'L0_S8', 'L0_S9',
     'L0_S10', 'L0_S11', 'L0_S12', 'L0_S13', 'L0_S14', 'L0_S15',
     'L0_S16', 'L0_S17', 'L0_S18', 'L0_S19', 'L0_S20', 'L0_S21', 'L0_S22', 
     'L0_S23', 'L1_S24', 'L1_S25', 'L2_S26', 'L2_S27', 'L2_S28',
     'L3_S29', 'L3_S30', 'L3_S31', 'L3_S32', 'L3_S33', 'L3_S34', 'L3_S35',
     'L3_S36', 'L3_S37', 'L3_S38', 'L3_S39', 'L3_S40', 'L3_S41', 'L3_S43',
     'L3_S44', 'L3_S45', 'L3_S47', 'L3_S48', 'L3_S49', 'L3_S50', 'L3_S51']




    df_pivot = df_pivot[col]
    
    print('append step: ')
    # %time final.append(df_pivot[col])

    i += 1
# Out:
# step: 0
# rename step:
# CPU times: user 57 s, sys: 972 ms, total: 58 s
# Wall time: 57.9 s
# group by step:
# CPU times: user 14.1 s, sys: 304 ms, total: 14.4 s
# Wall time: 9.76 s
# append step:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 3.7 ms
# step: 1
# rename step:
# CPU times: user 1min 2s, sys: 336 ms, total: 1min 2s
# Wall time: 1min 2s
# group by step:
# CPU times: user 13.9 s, sys: 272 ms, total: 14.2 s
# Wall time: 9.6 s
# append step:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 3.68 ms
# step: 2
# rename step:
# CPU times: user 1min 2s, sys: 156 ms, total: 1min 3s
# Wall time: 1min 2s
# group by step:
# CPU times: user 15.2 s, sys: 260 ms, total: 15.4 s
# Wall time: 10.6 s
# append step:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 3.68 ms
# step: 3
# rename step:
# CPU times: user 1min, sys: 228 ms, total: 1min 1s
# Wall time: 1min
# group by step:
# CPU times: user 17.2 s, sys: 328 ms, total: 17.5 s
# Wall time: 12.1 s
# ...

# %%
df_final = pd.concat(final, ignore_index=True)

msno.matrix(df_pivot.sort_values(col[1:], na_position='first'), labels=True)

# %%
df = pd.melt(reader.get_chunk(4000), id_vars = 'Id', value_vars=list(one_row.columns[1:-1]))

start = timeit.default_timer()
df['value'] = (df['value']/df['value'])
stop = timeit.default_timer()
print('division step: ' +str( stop - start)) 



start = timeit.default_timer()
df['variable_new'] = df['variable'].str.extract('(.*_.*_)', expand=True)
ddf = dd.from_pandas(df, chunksize=5000)
stop = timeit.default_timer()
print('extract station name step: ' +str( stop - start)) 


start = timeit.default_timer()
ddf_grouped = dd.groupby(['Id','variable_new'], sort=False).max()['value']
df_grouped = 
stop = timeit.default_timer()
print('groupby step: ' +str( stop - start)) 


start = timeit.default_timer()
df_pivot = pd.pivot_table(df_grouped, index='Id', columns='variable_new',
                         values='value', aggfunc=np.max).reset_index()
stop = timeit.default_timer()
print('pivot step: ' +str( stop - start)) 



col = ['Id', 'L0_S0_', 'L0_S1_', 'L0_S2_', 'L0_S3_', 'L0_S4_', 'L0_S5_', 'L0_S6_', 'L0_S7_', 'L0_S8_', 'L0_S9_',
 'L0_S10_', 'L0_S11_', 'L0_S12_', 'L0_S13_', 'L0_S14_', 'L0_S15_',
 'L0_S16_', 'L0_S17_', 'L0_S18_', 'L0_S19_',  'L0_S20_', 'L0_S21_', 'L0_S22_', 
 'L0_S23_', 'L1_S24_', 'L1_S25_', 'L2_S26_', 'L2_S27_', 'L2_S28_',
 'L3_S29_', 'L3_S30_', 'L3_S31_', 'L3_S32_', 'L3_S33_', 'L3_S34_', 'L3_S35_',
 'L3_S36_', 'L3_S37_', 'L3_S38_', 'L3_S39_', 'L3_S40_', 'L3_S41_', 'L3_S43_',
 'L3_S44_', 'L3_S45_', 'L3_S47_', 'L3_S48_', 'L3_S49_', 'L3_S50_', 'L3_S51_']


start = timeit.default_timer()
df_pivot = df_pivot[col]
stop = timeit.default_timer()
print('rearrange step:' +str( stop - start)) 


start = timeit.default_timer()
msno.matrix(df_pivot.sort_values(col[1:], na_position='first'), labels=True)
stop = timeit.default_timer()
print('draw image step:' +str( stop - start)) 


#print(df_pivot)
# Out:
# division step: 0.017071285999918473
# extract station name step: 8.693558217999453
# groupby step: 43.30991043499944
# pivot step: 0.0857281589997001
# rearrange step:0.0007856249994802056
# draw image step:1.6487951799999792
